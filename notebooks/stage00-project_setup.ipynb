# %%
# project path setup
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
SRC_PATH = PROJECT_ROOT / "src"

if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

# %%
from options_valuation.config import load_env, get_key, data_dir
from dotenv import load_dotenv
import numpy as np

load_dotenv(); load_env()

print("API_key:", get_key("API_KEY") is not None) # load Alpha Vantage API key
print("data_direction:", data_dir())
# Out:
# API_key: True
# data_direction: /Users/allenpilipala/BSM_model/data
